# %%
import os
from typing import Text
 
from absl import logging
from tfx.orchestration import metadata, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner

# %%
PIPELINE_NAME = "rivalhaikalhafizh-pipeline"
 
# pipeline inputs
DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/bmi_transform.py"
TRAINER_MODULE_FILE = "modules/bmi_trainer.py"
TUNER_MODULE_FILE = "modules/bmi_tuner.py"
# requirement_file = os.path.join(root, "requirements.txt")
 
# pipeline outputs
OUTPUT_BASE = "output"
serving_model_dir = os.path.join(OUTPUT_BASE, 'serving_model')
pipeline_roots = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_roots, "metadata.sqlite")

# %%
def init_local_pipeline(
    components, pipeline_root: Text
) -> pipeline.Pipeline:
    """Initiate tfx pipeline
    Args:
        pipeline_root (Text): a path to th pipeline directory
        pipeline_name (str): pipeline name
        metadata_path (str): a path to the metadata directory
        components (dict): tfx components
    Returns:
        pipeline.Pipeline: pipeline orchestration
    """
    
    logging.info(f"Pipeline root set to: {pipeline_root}")
    beam_args = [
        "--direct_running_mode=multi_processing"
        # 0 auto-detect based on on the number of CPUs available 
        # during execution time.
        "----direct_num_workers=0" 
    ]
    
    return pipeline.Pipeline(
        pipeline_name=PIPELINE_NAME,
        pipeline_root=pipeline_root,
        components=components,
        enable_cache=True,
        metadata_connection_config=metadata.sqlite_metadata_connection_config(
            metadata_path
        ),
        eam_pipeline_args=beam_args
    )

# %%
if __name__ == "__main__":
    logging.set_verbosity(logging.INFO)
    
    from modules.components import init_components
    components_args = {
        "data_dir": DATA_ROOT,
        "training_module": TRAINER_MODULE_FILE,
        "tuner_module": TUNER_MODULE_FILE,
        "transform_module": TRANSFORM_MODULE_FILE,
        "training_steps": 300,
        "eval_steps": 200,
        "serving_model_dir": serving_model_dir,
    }
    
    componentss = init_components(components_args)
    
    pipeline = init_local_pipeline(componentss, pipeline_roots)
    BeamDagRunner().run(pipeline=pipeline)
# Out:
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Pipeline root set to: outputs\rivalhaikalhafizh-pipeline
# INFO:absl:Generating ephemeral wheel package for 'C:\\Users\\ACER\\MachineLearning\\MLOps\\pipelineakhir\\modules\\bmi_transform.py' (including modules: ['bmi_trainer', 'bmi_transform', 'bmi_tuner', 'components']).
# INFO:absl:User module package has hash fingerprint version d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4.
# INFO:absl:Executing: ['C:\\Users\\ACER\\.conda\\envs\\a443-churn\\python.exe', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmp7uor30lk\\_tfx_generated_setup.py', 'bdist_wheel', '--bdist-dir', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmplzcn1_l8', '--dist-dir', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmpu7qzh3h9']
# INFO:absl:Successfully built user code wheel distribution at 'outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Transform-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl'; target user module is 'bmi_transform'.
# INFO:absl:Full user module path is 'bmi_transform@outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Transform-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl'
# INFO:absl:Generating ephemeral wheel package for 'C:\\Users\\ACER\\MachineLearning\\MLOps\\pipelineakhir\\modules\\bmi_tuner.py' (including modules: ['bmi_trainer', 'bmi_transform', 'bmi_tuner', 'components']).
# INFO:absl:User module package has hash fingerprint version d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4.
# INFO:absl:Executing: ['C:\\Users\\ACER\\.conda\\envs\\a443-churn\\python.exe', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmpvweg291_\\_tfx_generated_setup.py', 'bdist_wheel', '--bdist-dir', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmph27ijvvt', '--dist-dir', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmp4i18gr0u']
# INFO:absl:Successfully built user code wheel distribution at 'outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Tuner-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl'; target user module is 'bmi_tuner'.
# INFO:absl:Full user module path is 'bmi_tuner@outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Tuner-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl'
# INFO:absl:Generating ephemeral wheel package for 'C:\\Users\\ACER\\MachineLearning\\MLOps\\pipelineakhir\\modules\\bmi_trainer.py' (including modules: ['bmi_trainer', 'bmi_transform', 'bmi_tuner', 'components']).
# INFO:absl:User module package has hash fingerprint version d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4.
# INFO:absl:Executing: ['C:\\Users\\ACER\\.conda\\envs\\a443-churn\\python.exe', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmpypmzuaqq\\_tfx_generated_setup.py', 'bdist_wheel', '--bdist-dir', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmparer68oj', '--dist-dir', 'C:\\Users\\ACER\\AppData\\Local\\Temp\\tmpj1k7k_tg']
# INFO:absl:Successfully built user code wheel distribution at 'outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl'; target user module is 'bmi_trainer'.
# INFO:absl:Full user module path is 'bmi_trainer@outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl'
# INFO:absl:Using deployment config:
#  executor_specs {
#   key: "CsvExampleGen"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.example_gen.csv_example_gen.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "Evaluator"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.evaluator.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "ExampleValidator"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.example_validator.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "Pusher"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.pusher.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "SchemaGen"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.schema_gen.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "StatisticsGen"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.statistics_gen.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "Trainer"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.trainer.executor.GenericExecutor"
#     }
#   }
# }
# executor_specs {
#   key: "Transform"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.transform.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "Tuner"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.tuner.executor.Executor"
#     }
#   }
# }
# custom_driver_specs {
#   key: "CsvExampleGen"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.example_gen.driver.FileBasedDriver"
#     }
#   }
# }
# metadata_connection_config {
#   database_connection_config {
#     sqlite {
#       filename_uri: "outputs\\rivalhaikalhafizh-pipeline\\metadata.sqlite"
#       connection_mode: READWRITE_OPENCREATE
#     }
#   }
# }
#
# INFO:absl:Using connection config:
#  sqlite {
#   filename_uri: "outputs\\rivalhaikalhafizh-pipeline\\metadata.sqlite"
#   connection_mode: READWRITE_OPENCREATE
# }
#
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# INFO:absl:Node CsvExampleGen depends on [].
# INFO:absl:Node CsvExampleGen is scheduled.
# INFO:absl:Node Latest_blessed_model_resolver depends on [].
# INFO:absl:Node Latest_blessed_model_resolver is scheduled.
# INFO:absl:Node StatisticsGen depends on ['Run[CsvExampleGen]'].
# INFO:absl:Node StatisticsGen is scheduled.
# INFO:absl:Node SchemaGen depends on ['Run[StatisticsGen]'].
# INFO:absl:Node SchemaGen is scheduled.
# INFO:absl:Node ExampleValidator depends on ['Run[SchemaGen]', 'Run[StatisticsGen]'].
# INFO:absl:Node ExampleValidator is scheduled.
# INFO:absl:Node Transform depends on ['Run[CsvExampleGen]', 'Run[SchemaGen]'].
# INFO:absl:Node Transform is scheduled.
# INFO:absl:Node Tuner depends on ['Run[SchemaGen]', 'Run[Transform]'].
# INFO:absl:Node Tuner is scheduled.
# INFO:absl:Node Trainer depends on ['Run[SchemaGen]', 'Run[Transform]', 'Run[Tuner]'].
# INFO:absl:Node Trainer is scheduled.
# INFO:absl:Node Evaluator depends on ['Run[CsvExampleGen]', 'Run[Latest_blessed_model_resolver]', 'Run[Trainer]'].
# INFO:absl:Node Evaluator is scheduled.
# INFO:absl:Node Pusher depends on ['Run[Evaluator]', 'Run[Trainer]'].
# INFO:absl:Node Pusher is scheduled.
# INFO:absl:node CsvExampleGen is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.example_gen.csv_example_gen.component.CsvExampleGen"
#   }
#   id: "CsvExampleGen"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20230426-175403.011724"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline.CsvExampleGen"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "examples"
#     value {
#       artifact_spec {
#         type {
#           name: "Examples"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           properties {
#             key: "version"
#             value: INT
#           }
#           base_type: DATASET
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "input_base"
#     value {
#       field_value {
#         string_value: "data"
#       }
#     }
#   }
#   parameters {
#     key: "input_config"
#     value {
#       field_value {
#         string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"single_split\",\n      \"pattern\": \"*\"\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "output_config"
#     value {
#       field_value {
#         string_value: "{\n  \"split_config\": {\n    \"splits\": [\n      {\n        \"hash_buckets\": 8,\n        \"name\": \"train\"\n      },\n      {\n        \"hash_buckets\": 2,\n        \"name\": \"eval\"\n      }\n    ]\n  }\n}"
#       }
#     }
#   }
#   parameters {
#     key: "output_data_format"
#     value {
#       field_value {
#         int_value: 6
#       }
#     }
#   }
#   parameters {
#     key: "output_file_format"
#     value {
#       field_value {
#         int_value: 5
#       }
#     }
#   }
# }
# downstream_nodes: "Evaluator"
# downstream_nodes: "StatisticsGen"
# downstream_nodes: "Transform"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:[CsvExampleGen] Resolved inputs: ({},)
# INFO:absl:select span and version = (0, None)
# INFO:absl:latest span and version = (0, None)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 90 is used.
# INFO:absl:node CsvExampleGen is finished.
# INFO:absl:node Latest_blessed_model_resolver is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.dsl.components.common.resolver.Resolver"
#   }
#   id: "Latest_blessed_model_resolver"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20230426-175403.011724"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline.Latest_blessed_model_resolver"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "_generated_model_3"
#     value {
#       channels {
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#       }
#       hidden: true
#     }
#   }
#   inputs {
#     key: "_generated_modelblessing_4"
#     value {
#       channels {
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#       }
#       hidden: true
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       input_graph_ref {
#         graph_id: "graph_1"
#         key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       input_graph_ref {
#         graph_id: "graph_1"
#         key: "model_blessing"
#       }
#     }
#   }
#   input_graphs {
#     key: "graph_1"
#     value {
#       nodes {
#         key: "dict_2"
#         value {
#           output_data_type: ARTIFACT_MULTIMAP
#           dict_node {
#             node_ids {
#               key: "model"
#               value: "input_3"
#             }
#             node_ids {
#               key: "model_blessing"
#               value: "input_4"
#             }
#           }
#         }
#       }
#       nodes {
#         key: "input_3"
#         value {
#           output_data_type: ARTIFACT_LIST
#           input_node {
#             input_key: "_generated_model_3"
#           }
#         }
#       }
#       nodes {
#         key: "input_4"
#         value {
#           output_data_type: ARTIFACT_LIST
#           input_node {
#             input_key: "_generated_modelblessing_4"
#           }
#         }
#       }
#       nodes {
#         key: "op_1"
#         value {
#           output_data_type: ARTIFACT_MULTIMAP
#           op_node {
#             op_type: "tfx.dsl.input_resolution.strategies.latest_blessed_model_strategy.LatestBlessedModelStrategy"
#             args {
#               node_id: "dict_2"
#             }
#           }
#         }
#       }
#       result_node: "op_1"
#     }
#   }
# }
# downstream_nodes: "Evaluator"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:Running as an resolver node.
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Latest_blessed_model_resolver] Resolved inputs: ({'model_blessing': [Artifact(artifact: id: 18
# type_id: 34
# uri: "output\\rivalhaikalhafizh-pipeline\\Evaluator\\blessing\\9"
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\rivalhaikalhafizh-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 15
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682485580880
# last_update_time_since_epoch: 1682485580880
# , artifact_type: id: 34
# name: "ModelBlessing"
# )], 'model': [Artifact(artifact: id: 15
# type_id: 30
# uri: "output\\rivalhaikalhafizh-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682485540449
# last_update_time_since_epoch: 1682485540449
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )]},)
# INFO:absl:node Latest_blessed_model_resolver is finished.
# INFO:absl:node StatisticsGen is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.statistics_gen.component.StatisticsGen"
#     base_type: PROCESS
#   }
#   id: "StatisticsGen"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20230426-175403.011724"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline.StatisticsGen"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "statistics"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleStatistics"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           base_type: STATISTICS
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "exclude_splits"
#     value {
#       field_value {
#         string_value: "[]"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# downstream_nodes: "ExampleValidator"
# downstream_nodes: "SchemaGen"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[StatisticsGen] Resolved inputs: ({'examples': [Artifact(artifact: id: 125
# type_id: 16
# uri: "outputs\\rivalhaikalhafizh-pipeline\\CsvExampleGen\\examples\\81"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:8318,xor_checksum:1640319368,sum_checksum:1640319368"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506325519
# last_update_time_since_epoch: 1682506325519
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 92 is used.
# INFO:absl:node StatisticsGen is finished.
# INFO:absl:node SchemaGen is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.schema_gen.component.SchemaGen"
#     base_type: PROCESS
#   }
#   id: "SchemaGen"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20230426-175403.011724"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline.SchemaGen"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "statistics"
#     value {
#       channels {
#         producer_node_query {
#           id: "StatisticsGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.StatisticsGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ExampleStatistics"
#             base_type: STATISTICS
#           }
#         }
#         output_key: "statistics"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "schema"
#     value {
#       artifact_spec {
#         type {
#           name: "Schema"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "exclude_splits"
#     value {
#       field_value {
#         string_value: "[]"
#       }
#     }
#   }
#   parameters {
#     key: "infer_feature_shape"
#     value {
#       field_value {
#         int_value: 1
#       }
#     }
#   }
# }
# upstream_nodes: "StatisticsGen"
# downstream_nodes: "ExampleValidator"
# downstream_nodes: "Trainer"
# downstream_nodes: "Transform"
# downstream_nodes: "Tuner"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[SchemaGen] Resolved inputs: ({'statistics': [Artifact(artifact: id: 126
# type_id: 18
# uri: "outputs\\rivalhaikalhafizh-pipeline\\StatisticsGen\\statistics\\83"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506330975
# last_update_time_since_epoch: 1682506330975
# , artifact_type: id: 18
# name: "ExampleStatistics"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# base_type: STATISTICS
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 93 is used.
# INFO:absl:node SchemaGen is finished.
# INFO:absl:node Transform is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.transform.component.Transform"
#     base_type: TRANSFORM
#   }
#   id: "Transform"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20230426-175403.011724"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline.Transform"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "post_transform_anomalies"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleAnomalies"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#         }
#       }
#     }
#   }
#   outputs {
#     key: "post_transform_schema"
#     value {
#       artifact_spec {
#         type {
#           name: "Schema"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "post_transform_stats"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleStatistics"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           base_type: STATISTICS
#         }
#       }
#     }
#   }
#   outputs {
#     key: "pre_transform_schema"
#     value {
#       artifact_spec {
#         type {
#           name: "Schema"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "pre_transform_stats"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleStatistics"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           base_type: STATISTICS
#         }
#       }
#     }
#   }
#   outputs {
#     key: "transform_graph"
#     value {
#       artifact_spec {
#         type {
#           name: "TransformGraph"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "transformed_examples"
#     value {
#       artifact_spec {
#         type {
#           name: "Examples"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           properties {
#             key: "version"
#             value: INT
#           }
#           base_type: DATASET
#         }
#       }
#     }
#   }
#   outputs {
#     key: "updated_analyzer_cache"
#     value {
#       artifact_spec {
#         type {
#           name: "TransformCache"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "disable_statistics"
#     value {
#       field_value {
#         int_value: 0
#       }
#     }
#   }
#   parameters {
#     key: "force_tf_compat_v1"
#     value {
#       field_value {
#         int_value: 0
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "bmi_transform@outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Transform-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "SchemaGen"
# downstream_nodes: "Trainer"
# downstream_nodes: "Tuner"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Transform] Resolved inputs: ({'examples': [Artifact(artifact: id: 125
# type_id: 16
# uri: "outputs\\rivalhaikalhafizh-pipeline\\CsvExampleGen\\examples\\81"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:8318,xor_checksum:1640319368,sum_checksum:1640319368"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506325519
# last_update_time_since_epoch: 1682506325519
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'schema': [Artifact(artifact: id: 127
# type_id: 20
# uri: "outputs\\rivalhaikalhafizh-pipeline\\SchemaGen\\schema\\84"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506331203
# last_update_time_since_epoch: 1682506331203
# , artifact_type: id: 20
# name: "Schema"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 94 is used.
# INFO:absl:node Transform is finished.
# INFO:absl:node ExampleValidator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.example_validator.component.ExampleValidator"
#   }
#   id: "ExampleValidator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20230426-175403.011724"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline.ExampleValidator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "statistics"
#     value {
#       channels {
#         producer_node_query {
#           id: "StatisticsGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.StatisticsGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ExampleStatistics"
#             base_type: STATISTICS
#           }
#         }
#         output_key: "statistics"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "anomalies"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleAnomalies"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "exclude_splits"
#     value {
#       field_value {
#         string_value: "[]"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "StatisticsGen"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[ExampleValidator] Resolved inputs: ({'statistics': [Artifact(artifact: id: 126
# type_id: 18
# uri: "outputs\\rivalhaikalhafizh-pipeline\\StatisticsGen\\statistics\\83"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506330975
# last_update_time_since_epoch: 1682506330975
# , artifact_type: id: 18
# name: "ExampleStatistics"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# base_type: STATISTICS
# )], 'schema': [Artifact(artifact: id: 127
# type_id: 20
# uri: "outputs\\rivalhaikalhafizh-pipeline\\SchemaGen\\schema\\84"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506331203
# last_update_time_since_epoch: 1682506331203
# , artifact_type: id: 20
# name: "Schema"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 95 is used.
# INFO:absl:node ExampleValidator is finished.
# INFO:absl:node Tuner is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.tuner.component.Tuner"
#   }
#   id: "Tuner"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20230426-175403.011724"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline.Tuner"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "best_hyperparameters"
#     value {
#       artifact_spec {
#         type {
#           name: "HyperParameters"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "tuner_results"
#     value {
#       artifact_spec {
#         type {
#           name: "TunerResults"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 200,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "bmi_tuner@outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Tuner-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 300,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# downstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Tuner] Resolved inputs: ({'transform_graph': [Artifact(artifact: id: 134
# type_id: 22
# uri: "outputs\\rivalhaikalhafizh-pipeline\\Transform\\transform_graph\\86"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506352678
# last_update_time_since_epoch: 1682506352678
# , artifact_type: id: 22
# name: "TransformGraph"
# )], 'examples': [Artifact(artifact: id: 130
# type_id: 16
# uri: "outputs\\rivalhaikalhafizh-pipeline\\Transform\\transformed_examples\\86"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506352677
# last_update_time_since_epoch: 1682506352677
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'schema': [Artifact(artifact: id: 127
# type_id: 20
# uri: "outputs\\rivalhaikalhafizh-pipeline\\SchemaGen\\schema\\84"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506331203
# last_update_time_since_epoch: 1682506331203
# , artifact_type: id: 20
# name: "Schema"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 96 is used.
# INFO:absl:node Tuner is finished.
# INFO:absl:node Trainer is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20230426-175403.011724"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "rivalhaikalhafizh-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20230426-175403.011724"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "rivalhaikalhafizh-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 200,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "bmi_trainer@outputs\\rivalhaikalhafizh-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+d2501d74274dc09e60935ad38c6386c7b723d4fe727ab7b36bfe796966d298e4-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 300,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Trainer] Resolved inputs: ({'transform_graph': [Artifact(artifact: id: 134
# type_id: 22
# uri: "outputs\\rivalhaikalhafizh-pipeline\\Transform\\transform_graph\\86"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1682506352678
# last_update_time_since_epoch: 1682506352678
# , artifact_type: id: 22
# name: "TransformGraph"
# )], 'schema': [Artifact(artifact: id: 127
# type_id: 20
# uri: "outputs\\rivalhaikalhafizh-pipeline\\SchemaGen\\schema\\84"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# ...
#     230       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     231           input_stream, True)
# --> 232       self.output(decoded_value)
#     233
#     234   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      88
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#      92
#
# ~\AppData\Roaming\Python\Python39\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      97       with metadata.Metadata(self._mlmd_connection_config) as mlmd_handle:
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#     101         mlmd_connection=metadata.Metadata(self._mlmd_connection_config),
#
# ~\AppData\Roaming\Python\Python39\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     571               executor_watcher.address)
#     572           executor_watcher.start()
# --> 573         executor_output = self._run_executor(execution_info)
#     574       except Exception as e:  # pylint: disable=broad-except
#     575         execution_output = (
#
# ~\AppData\Roaming\Python\Python39\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     446     outputs_utils.make_output_dirs(execution_info.output_dict)
#     447     try:
# --> 448       executor_output = self._executor_operator.run_executor(execution_info)
#     449       code = executor_output.execution_result.code
#     450       if code != 0:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tfx\orchestration\portable\beam_executor_operator.py in run_executor(self, execution_info, make_beam_pipeline_fn)
#     110         make_beam_pipeline_fn=make_beam_pipeline_fn)
#     111     executor = self._executor_cls(context=context)
# --> 112     return python_executor_operator.run_with_executor(execution_info, executor)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      56
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#      60   if not result:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tfx\components\evaluator\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     290               tensor_adapter_config=tensor_adapter_config)
#     291
# --> 292         (examples_list | 'FlattenExamples' >> beam.Flatten()
#     293          | 'ExtractEvaluateAndWriteResults' >>
#     294          (tfma.ExtractEvaluateAndWriteResults(
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     598     try:
#     599       if not exc_type:
# --> 600         self.result = self.run()
#     601         self.result.wait_until_finish()
#     602     finally:
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in run(self, test_runner_api)
#     575         finally:
#     576           shutil.rmtree(tmpdir)
# --> 577       return self.runner.run_pipeline(self, self._options)
#     578     finally:
#     579       if not is_in_ipython():
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\direct\direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_pipeline(self, pipeline, options)
#     201
#     202     self._latest_run_result = self.run_via_runner_api(
# --> 203         pipeline.to_runner_api(default_environment=self._default_environment),
#     204         options)
#     205     return self._latest_run_result
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in to_runner_api(self, return_context, context, use_fake_coders, default_environment)
#     915     # Mutates context; placing inline would force dependence on
#     916     # argument evaluation order.
# --> 917     root_transform_id = context.transforms.get_id(self._root_transform())
#     918     proto = beam_runner_api_pb2.Pipeline(
#     919         root_transform_ids=[root_transform_id],
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\pipeline_context.py in get_id(self, obj, label)
#     102       self._id_to_obj[id] = obj
#     103       self._obj_to_id[obj] = id
# --> 104       self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105     return self._obj_to_id[obj]
#     106
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in to_runner_api(self, context)
#    1342         unique_name=self.full_label,
#    1343         spec=transform_spec,
# -> 1344         subtransforms=[
#    1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in <listcomp>(.0)
#    1343         spec=transform_spec,
#    1344         subtransforms=[
# -> 1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#    1347         ],
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\pipeline_context.py in get_id(self, obj, label)
#     102       self._id_to_obj[id] = obj
#     103       self._obj_to_id[obj] = id
# --> 104       self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105     return self._obj_to_id[obj]
#     106
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in to_runner_api(self, context)
#    1342         unique_name=self.full_label,
#    1343         spec=transform_spec,
# -> 1344         subtransforms=[
#    1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in <listcomp>(.0)
#    1343         spec=transform_spec,
#    1344         subtransforms=[
# -> 1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#    1347         ],
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\pipeline_context.py in get_id(self, obj, label)
#     102       self._id_to_obj[id] = obj
#     103       self._obj_to_id[obj] = id
# --> 104       self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105     return self._obj_to_id[obj]
#     106
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in to_runner_api(self, context)
#    1342         unique_name=self.full_label,
#    1343         spec=transform_spec,
# -> 1344         subtransforms=[
#    1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in <listcomp>(.0)
#    1343         spec=transform_spec,
#    1344         subtransforms=[
# -> 1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#    1347         ],
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\pipeline_context.py in get_id(self, obj, label)
#     102       self._id_to_obj[id] = obj
#     103       self._obj_to_id[obj] = id
# --> 104       self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105     return self._obj_to_id[obj]
#     106
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in to_runner_api(self, context)
#    1342         unique_name=self.full_label,
#    1343         spec=transform_spec,
# -> 1344         subtransforms=[
#    1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in <listcomp>(.0)
#    1343         spec=transform_spec,
#    1344         subtransforms=[
# -> 1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#    1347         ],
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\pipeline_context.py in get_id(self, obj, label)
#     102       self._id_to_obj[id] = obj
#     103       self._obj_to_id[obj] = id
# --> 104       self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105     return self._obj_to_id[obj]
#     106
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in to_runner_api(self, context)
#    1342         unique_name=self.full_label,
#    1343         spec=transform_spec,
# -> 1344         subtransforms=[
#    1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in <listcomp>(.0)
#    1343         spec=transform_spec,
#    1344         subtransforms=[
# -> 1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#    1347         ],
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\pipeline_context.py in get_id(self, obj, label)
#     102       self._id_to_obj[id] = obj
#     103       self._obj_to_id[obj] = id
# --> 104       self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105     return self._obj_to_id[obj]
#     106
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in to_runner_api(self, context)
#    1342         unique_name=self.full_label,
#    1343         spec=transform_spec,
# -> 1344         subtransforms=[
#    1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in <listcomp>(.0)
#    1343         spec=transform_spec,
#    1344         subtransforms=[
# -> 1345             context.transforms.get_id(part, label=part.full_label)
#    1346             for part in self.parts
#    1347         ],
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\runners\pipeline_context.py in get_id(self, obj, label)
#     102       self._id_to_obj[id] = obj
#     103       self._obj_to_id[obj] = id
# --> 104       self._id_to_proto[id] = obj.to_runner_api(self._pipeline_context)
#     105     return self._obj_to_id[obj]
#     106
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in to_runner_api(self, context)
#    1331     # Iterate over inputs and outputs by sorted key order, so that ids are
#    1332     # consistently generated for multiple runs of the same pipeline.
# -> 1333     transform_spec = transform_to_runner_api(self.transform, context)
#    1334     environment_id = self.environment_id
#    1335     transform_urn = transform_spec.urn if transform_spec else None
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in transform_to_runner_api(transform, context)
#    1323         # key_coder and window_coder to stateful DoFn.
#    1324         if isinstance(transform, ParDo):
# -> 1325           return transform.to_runner_api(
#    1326               context,
#    1327               has_parts=bool(self.parts),
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\transforms\ptransform.py in to_runner_api(self, context, has_parts, **extra_kwargs)
#     743     from apache_beam.portability.api import beam_runner_api_pb2
#     744     # typing: only ParDo supports extra_kwargs
# --> 745     urn, typed_param = self.to_runner_api_parameter(context, **extra_kwargs)  # type: ignore[call-arg]
#     746     if urn == python_urns.GENERIC_COMPOSITE_TRANSFORM and not has_parts:
#     747       # TODO(https://github.com/apache/beam/issues/18713): Remove this fallback.
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\transforms\core.py in to_runner_api_parameter(self, context, **extra_kwargs)
#    1693         common_urns.primitives.PAR_DO.urn,
#    1694         beam_runner_api_pb2.ParDoPayload(
# -> 1695             do_fn=self._do_fn_info().to_runner_api(context),
#    1696             requests_finalization=has_bundle_finalization,
#    1697             restriction_coder_id=restriction_coder_id,
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\transforms\core.py in _do_fn_info(self)
#    1640
#    1641   def _do_fn_info(self):
# -> 1642     return DoFnInfo.create(self.fn, self.args, self.kwargs)
#    1643
#    1644   def _get_key_and_window_coder(self, named_inputs):
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\transforms\core.py in create(cls, fn, args, kwargs)
#    1789       return StatelessDoFnInfo(fn._stateless_dofn_urn)
#    1790     else:
# -> 1791       return PickledDoFnInfo(cls._pickled_do_fn_info(fn, args, kwargs))
#    1792
#    1793   @staticmethod
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\transforms\core.py in _pickled_do_fn_info(fn, args, kwargs)
#    1803   def _pickled_do_fn_info(fn, args, kwargs):
#    1804     # This can be cleaned up once all runners move to portability.
# -> 1805     return pickler.dumps((fn, args, kwargs, None, None))
#    1806
#    1807   def serialized_dofn_data(self):
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\internal\pickler.py in dumps(o, enable_trace, use_zlib)
#      42   # type: (...) -> bytes
#      43
# ---> 44   return desired_pickle_lib.dumps(
#      45       o, enable_trace=enable_trace, use_zlib=use_zlib)
#      46
#
# ~\.conda\envs\a443-churn\lib\site-packages\apache_beam\internal\dill_pickler.py in dumps(o, enable_trace, use_zlib)
#     263     c = zlib.compress(s, 9)
#     264   else:
# --> 265     c = bz2.compress(s, compresslevel=9)
#     266   del s  # Free up some possibly large and no-longer-needed memory.
#     267
#
# ~\.conda\envs\a443-churn\lib\bz2.py in compress(data, compresslevel)
#     333     """
#     334     comp = BZ2Compressor(compresslevel)
# --> 335     return comp.compress(data) + comp.flush()
#     336
#     337
#
# RuntimeError: KeyboardInterrupt [while running 'Run[Evaluator]']
